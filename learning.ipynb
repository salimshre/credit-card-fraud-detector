# %% [markdown]
# print('hello')

# %% [markdown]
# 2+3

# %% [markdown]
# !pip install joblib scikit-learn matplotlib numpy pandas seaborn

# %% [markdown]
# import sys
# print(sys.executable)          # shows which Python interpreter the notebook uses
# print(sys.version)

# %% [markdown]
# !{sys.executable} -m pip install joblib scikit-learn matplotlib numpy pandas seaborn

# %% [markdown]
# import sys
# print(sys.executable)

# %% [markdown]
# import sys
# !{sys.executable} -m pip install joblib scikit-learn matplotlib numpy pandas seaborn

# %% [markdown]
# import IPython
# IPython.Application.instance().kernel.do_shutdown(True)  # This will restart the kernel

# %% [markdown]
# import json
# from datetime import datetime, timezone
# from pathlib import Path
#
# import joblib
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
#
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report

# %% [markdown]
# import math
# math.sqrt(25)

# %% [markdown]
# import json
#
# student = {
#     "name":"salim",
#     "age": 25
# }
#
# text = json.dumps(student)
# print(text)

# %% [markdown]
# from datetime import datetime
#
# now = datetime.now()
#
# print(now)

# %% [markdown]
# **datetime.now() is like looking at the clock on your wall. It tells you "right now, this is the date and time". In your fraud system, that timestamp is attached to every transaction, alert, and verification so you know exactly when everything happened – essential for auditing and debugging!**

# %% [markdown]
# from pathlib import Path
# file = Path("creditcard.csv")
# print(file.exists())

# %% [markdown]
# from datetime import datetime
# from pathlib import Path
#
# print(datetime.now())
#
# file = Path("creditcard_raw.csv")
# print(file.exists())
