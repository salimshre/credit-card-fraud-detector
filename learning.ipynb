# %%
print('hello')

# %%
2+3

# %%
# !pip install joblib scikit-learn matplotlib numpy pandas seaborn

# %%
import sys
print(sys.executable)          # shows which Python interpreter the notebook uses
print(sys.version)

# %%
# !{sys.executable} -m pip install joblib scikit-learn matplotlib numpy pandas seaborn

# %%
import sys
print(sys.executable)

# %%
import sys
# !{sys.executable} -m pip install joblib scikit-learn matplotlib numpy pandas seaborn

# %%
import IPython
IPython.Application.instance().kernel.do_shutdown(True)  # This will restart the kernel

# %%
import json
from datetime import datetime, timezone
from pathlib import Path

import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
import math
math.sqrt(25)

# %%
import json

student = {
    "name":"salim",
    "age": 25
}

text = json.dumps(student)
print(text)

# %%
from datetime import datetime

now = datetime.now()

print(now)

# %%
**datetime.now() is like looking at the clock on your wall. It tells you "right now, this is the date and time". In your fraud system, that timestamp is attached to every transaction, alert, and verification so you know exactly when everything happened – essential for auditing and debugging!**

# %%
from pathlib import Path
file = Path("creditcard.csv")
print(file.exists())

# %%
from datetime import datetime
from pathlib import Path

print(datetime.now())

file = Path("creditcard_raw.csv")
print(file.exists())

# %% [markdown]
# **next stps**

# %%
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import joblib

student = {
    "name": "salim",
    "age": 25
}

joblib.dump(student, "student.pkl")
# Out:
# ['student.pkl']

# %%
student = joblib.load("student.pkl")
print(student)
# Out:
# {'name': 'salim', 'age': 25}

# %% [markdown]
# # in my project
# model.fit(X_train, y_train)
# joblib.dump(model), "fraud_model.pkl")
# model = joblib.load("fraud_model.pkl")

# %%
import numpy as np
numbers = [2,4,6,8]

# %%
#without numpy
result = [2, 4, 6, 8]
doubled = []  # empty list to store the new values

for x in result:
    doubled.append(x * 2)

print(doubled)  # Output: [4, 8, 12, 16]
# Out:
# [4, 8, 12, 16]

# %%
#with numpy
import numpy as np
numbers = np.array([2,4,6,8])
print(numbers * 2)
# Out:
# [ 4  8 12 16]

# %%
import pandas as pd

students = {
    "name": ["salim", "ram","sita"],
    "age": [25,30,22] 
}

df = pd.DataFrame(students)
print(df)
# Out:
#     name  age
# 0  salim   25
# 1    ram   30
# 2   sita   22

# %%
# to load datasets
df = pd.read_csv("creditcard_raw.csv")
print(df)
# Out:
#       transaction_date transaction_time customer_id  card_last4      merchant  \
# 0           2023-07-18         08:13:40   CUST-3977        3977  Merchant_338
# 1           2023-01-22         11:33:08   CUST-1400        1400  Merchant_321
# 2           2023-01-31         12:24:09   CUST-3724        3724  Merchant_127
# 3           2023-08-27         19:00:04   CUST-6688        6688   Merchant_26
# 4           2023-03-05         10:40:29   CUST-6688        6688   Merchant_30
# ...                ...              ...         ...         ...           ...
# 59973       2023-04-20         07:40:27   CUST-6355        6355  Merchant_107
# 59974       2023-08-05         11:51:08   CUST-6139        6139  Merchant_255
# 59975       2023-05-06         11:11:25   CUST-7912        7912   Merchant_15
# 59976       2023-08-23         16:35:52   CUST-6107        6107  Merchant_342
# 59977       2023-04-18         14:02:11   CUST-8758        8758  Merchant_291
#
#       merchant_category  amount country channel  is_fraud
# 0                travel   50.91      DE     pos         0
# 1                travel   29.11      US     pos         0
# 2             utilities   37.55      CA     web         0
# 3            restaurant   21.60      AU     pos         0
# 4             utilities   20.34      AU     web         0
# ...                 ...     ...     ...     ...       ...
# 59973           grocery   96.57      GB     web         0
# 59974        restaurant   52.01      FR  mobile         0
# 59975       gas_station   58.69      CA  mobile         0
# 59976              cash   54.43      DE     pos         0
# 59977            online   58.12      GB     web         0
#
# [59978 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [2,4,6,8]

plt.plot(x,y)
plt.show()

# %%
names = ["fraud", "normal"]
values = [500, 10000]

plt.bar(names, values)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

numbers = np.array([10,20,30])
print(numbers * 2)

data = {
    "Name": ["salim","ram"],
    "age": [25,30]
}

df = pd.DataFrame(data)
print(df)

plt.plot([1,2,3], [2,4,6])
plt.show()
# Out:
# [20 40 60]
#     Name  age
# 0  salim   25
# 1    ram   30

# %% [markdown]
# # Next lesson
# **sklearn**
#
# ---
#
# cell 4

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# importing only one tool from sklearn.ensemble called RandomForestClassifer
from sklearn.ensemble import RandomForestClassifier
